# %% [markdown]
# <a href="https://colab.research.google.com/github/SridharChapparbande/Data-Science/blob/main/Credit_Status.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PROJECT: FACTOR INFLUENCING CREDITABILITY**

# %% [markdown]
# **CONTEXT:**
#
#
#
# *   The banks with the invent of the credit card were more focused on the number of customers using their credit service.
# *   But the drawback of them not being able to pay back the credit in time was an issue that soon followed.
#
#
# *   A system was in need to effectively decide the credit limit to be allowed to a person based on his previous credit history.
# *   So,an early prediction on this issue will be useful for banks.

# %% [markdown]
# **PROBLEM STATEMENT:**
#
#
# *   Does various predicting factors really affect creditability?
# *   What are the variables actually affecting creditability.
#
# *   what are the variables not affecting creditability.
# *   Does creditability depends on various variables/factors.

# %% [markdown]
# **ATTRIBUTE/VARIABLES INFORMATION:**
#
#
#
# *   Creditability :Credit Risks (0:Bad,1:Good)
#
# *   Account_balance:Status of existing checking account balance(1: ... < 0 DM
# 2: 0 <= ... < 200 DM Bank Credit Card Default Prediction
# 3: ... >= 200 DM / salary assignments for at least 1 year
# 4: no checking account)
#
#
#
# *   Credit_duration_months:Duration in month
#
# *   Previous_credit_payment_status: Credit history of the customer(0: no credits taken/all credits paid back duly
# 1: all credits at this bank paid back duly
# 2: existing credits paid back duly till now
# 3: delay in paying off in the past
# 4: critical account/other credits existing (not at this bank))
#
# *   credit_purpose:Purpose_of_loan(0: car (new),1: car (used),2: furniture/equipment,3: radio/television ,4: domestic appliances,5: repairs,6: education,7: (vacation - does not exist?),8: retraining,9: business,10: others
#
# *   Credit_amount:Credit amount issued
#
# *   Savings:Savings account/bonds(1: ... < 100 DM,2: 100 <= ... < 500 DM,3: 500 <= ... < 1000 DM,4: ... >= 1000 DM,5: unknown/ no savings account)
#
# *   Employment_duration:Present employment since(1: unemployed,2: ... < 1 year,3: 1 <= ... < 4 years,4: 4 <= ... < 7 years,5: .. >= 7 years)
#
# *   Installment_rate:Installment rate in percentage of disposable income
#
# *   Marital_status:Personal status and sex(1: male (divorced/separated),2: female (divorced/separated/married),3: male (single),4: male (married/widowed),5: female (single))
#
#
#
# *   Guarantor:Guarantors/Debtors: Other debtors / guarantors(1: none,2: co-applicant,3: guarantor)
#
# *   Residence_duration:Present residence since
#
# *   Age:Age in years
#
# *   Other_credits:Other instalment plans(1: bank,2: stores,3: none)
#
# *   Apartment_type:Housing(1:rent,2:own,3:for free)
#
# *   Bank_credits:Number of existing credits at this bank
#
# *   Occupation:Job
# (1: unemployed/ unskilled - non-resident
# 2: unskilled - resident
# 3: skilled employee/official
# 4: management/ self-employed/highly qualified employee/ officer)
#
# *   Dependents:Number of people being liable to provide maintenance for loan
#
#
#
# *   Telephone:Telephone(1: none,2: yes, registered under the customer’s name)
#
# *   Foreign_worker:whether works in foreign (yes=1,no=0)

# %% [markdown]
# **Steps involved in model Building:**
#
#
# *   Understanding the problem statement
#
# *   Overview of the data
#
#
# *   Data preparation / cleaning
#
# *   Model biulding / choose model,trian and evaluate
#
#
# *   Conclusion based on model

# %% [markdown]
# **Import Libraries:**

# %%
#importing the drive for required file
from google.colab import drive
drive.mount('/gdrive')
# %cd '/gdrive/My Drive/Colab Notebooks/PROJECT/Credit List'
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/Colab Notebooks/PROJECT/Credit List

# %%
#importing the required libraries
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# %% [markdown]
# **Read and Explore Data:**

# %%
#reading the original data using csv file
data = pd.read_csv("credit_dataset_final.csv")
data
# Out:
#      credit.rating  account.balance  credit.duration.months  \
# 0                1                1                      18
# 1                1                1                       9
# 2                1                2                      12
# 3                1                1                      12
# 4                1                1                      12
# ..             ...              ...                     ...
# 995              0                1                      24
# 996              0                1                      24
# 997              0                3                      21
# 998              0                2                      12
# 999              0                1                      30
#
#      previous.credit.payment.status  credit.purpose  credit.amount  savings  \
# 0                                 3               2           1049        1
# 1                                 3               4           2799        1
# 2                                 2               4            841        2
# 3                                 3               4           2122        1
# 4                                 3               4           2171        1
# ..                              ...             ...            ...      ...
# 995                               2               3           1987        1
# 996                               2               4           2303        1
# 997                               3               4          12680        4
# 998                               2               3           6468        4
# 999                               2               2           6350        4
#
#      employment.duration  installment.rate  marital.status  ...  \
# 0                      1                 4               1  ...
# 1                      2                 2               3  ...
# 2                      3                 2               1  ...
# 3                      2                 3               3  ...
# 4                      2                 4               3  ...
# ..                   ...               ...             ...  ...
# 995                    2                 2               3  ...
# 996                    4                 4               3  ...
# 997                    4                 4               3  ...
# 998                    1                 2               3  ...
# 999                    4                 4               3  ...
#
#      residence.duration  current.assets  age  other.credits  apartment.type  \
# 0                     4               2   21              2               1
# 1                     2               1   36              2               1
# 2                     4               1   23              2               1
# 3                     2               1   39              2               1
# 4                     4               2   38              1               2
# ..                  ...             ...  ...            ...             ...
# 995                   4               1   21              2               1
# 996                   1               1   45              2               2
# 997                   4               4   30              2               3
# 998                   1               4   52              2               2
# 999                   4               2   31              2               2
#
#      bank.credits  occupation  dependents  telephone  foreign.worker
# 0               1           3           1          1               1
# 1               2           3           2          1               1
# 2               1           2           1          1               1
# 3               2           2           2          1               2
# 4               2           2           1          1               2
# ..            ...         ...         ...        ...             ...
# 995             1           2           2          1               1
# 996             1           3           1          1               1
# 997             1           4           1          2               1
# 998             1           4           1          2               1
# 999             1           3           1          1               1
#
# [1000 rows x 21 columns]

# %%
#making the shallow copy of the data for EDA and data analysis 
#shalllow copy is made bcz  if any changes done that should not change in original data
df = data.copy()
df
# Out:
#      credit.rating  account.balance  credit.duration.months  \
# 0                1                1                      18
# 1                1                1                       9
# 2                1                2                      12
# 3                1                1                      12
# 4                1                1                      12
# ..             ...              ...                     ...
# 995              0                1                      24
# 996              0                1                      24
# 997              0                3                      21
# 998              0                2                      12
# 999              0                1                      30
#
#      previous.credit.payment.status  credit.purpose  credit.amount  savings  \
# 0                                 3               2           1049        1
# 1                                 3               4           2799        1
# 2                                 2               4            841        2
# 3                                 3               4           2122        1
# 4                                 3               4           2171        1
# ..                              ...             ...            ...      ...
# 995                               2               3           1987        1
# 996                               2               4           2303        1
# 997                               3               4          12680        4
# 998                               2               3           6468        4
# 999                               2               2           6350        4
#
#      employment.duration  installment.rate  marital.status  ...  \
# 0                      1                 4               1  ...
# 1                      2                 2               3  ...
# 2                      3                 2               1  ...
# 3                      2                 3               3  ...
# 4                      2                 4               3  ...
# ..                   ...               ...             ...  ...
# 995                    2                 2               3  ...
# 996                    4                 4               3  ...
# 997                    4                 4               3  ...
# 998                    1                 2               3  ...
# 999                    4                 4               3  ...
#
#      residence.duration  current.assets  age  other.credits  apartment.type  \
# 0                     4               2   21              2               1
# 1                     2               1   36              2               1
# 2                     4               1   23              2               1
# 3                     2               1   39              2               1
# 4                     4               2   38              1               2
# ..                  ...             ...  ...            ...             ...
# 995                   4               1   21              2               1
# 996                   1               1   45              2               2
# 997                   4               4   30              2               3
# 998                   1               4   52              2               2
# 999                   4               2   31              2               2
#
#      bank.credits  occupation  dependents  telephone  foreign.worker
# 0               1           3           1          1               1
# 1               2           3           2          1               1
# 2               1           2           1          1               1
# 3               2           2           2          1               2
# 4               2           2           1          1               2
# ..            ...         ...         ...        ...             ...
# 995             1           2           2          1               1
# 996             1           3           1          1               1
# 997             1           4           1          2               1
# 998             1           4           1          2               1
# 999             1           3           1          1               1
#
# [1000 rows x 21 columns]

# %% [markdown]
# **Overview of the Data:**

# %%
#checking the data of first five rows using head option
#By default head shows only five rows but u can get any numbers of rows using df.head(number)
df.head()
# Out:
#    credit.rating  account.balance  credit.duration.months  \
# 0              1                1                      18
# 1              1                1                       9
# 2              1                2                      12
# 3              1                1                      12
# 4              1                1                      12
#
#    previous.credit.payment.status  credit.purpose  credit.amount  savings  \
# 0                               3               2           1049        1
# 1                               3               4           2799        1
# 2                               2               4            841        2
# 3                               3               4           2122        1
# 4                               3               4           2171        1
#
#    employment.duration  installment.rate  marital.status  ...  \
# 0                    1                 4               1  ...
# 1                    2                 2               3  ...
# 2                    3                 2               1  ...
# 3                    2                 3               3  ...
# 4                    2                 4               3  ...
#
#    residence.duration  current.assets  age  other.credits  apartment.type  \
# 0                   4               2   21              2               1
# 1                   2               1   36              2               1
# 2                   4               1   23              2               1
# 3                   2               1   39              2               1
# 4                   4               2   38              1               2
#
#    bank.credits  occupation  dependents  telephone  foreign.worker
# 0             1           3           1          1               1
# 1             2           3           2          1               1
# 2             1           2           1          1               1
# 3             2           2           2          1               2
# 4             2           2           1          1               2
#
# [5 rows x 21 columns]

# %%
#to display maximum number of rows and columns instead of 1,2,.....,10
pd.set_option('display.max_columns', None )

# %%
#to display maximum number of rows and columns instead of 1,2,.....,10
pd.set_option('display.max_rows', None )

# %%
#checking the data of last five rows using tail option
#By default tail shows only five rows but u can get any numbers of rows using df.tail(number)
df.tail()
# Out:
#      credit.rating  account.balance  credit.duration.months  \
# 995              0                1                      24
# 996              0                1                      24
# 997              0                3                      21
# 998              0                2                      12
# 999              0                1                      30
#
#      previous.credit.payment.status  credit.purpose  credit.amount  savings  \
# 995                               2               3           1987        1
# 996                               2               4           2303        1
# 997                               3               4          12680        4
# 998                               2               3           6468        4
# 999                               2               2           6350        4
#
#      employment.duration  installment.rate  marital.status  guarantor  \
# 995                    2                 2               3          1
# 996                    4                 4               3          2
# 997                    4                 4               3          1
# 998                    1                 2               3          1
# 999                    4                 4               3          1
#
#      residence.duration  current.assets  age  other.credits  apartment.type  \
# 995                   4               1   21              2               1
# 996                   1               1   45              2               2
# 997                   4               4   30              2               3
# 998                   1               4   52              2               2
# 999                   4               2   31              2               2
#
#      bank.credits  occupation  dependents  telephone  foreign.worker
# 995             1           2           2          1               1
# 996             1           3           1          1               1
# 997             1           4           1          2               1
# 998             1           4           1          2               1
# 999             1           3           1          1               1

# %%
#getting all the information of dataset using info command 
#info command gives
  #1 No of rows 
  #2 No of columns 
  #3 No of float,int,object columns 
  #4 Datatype of all the columns
  #5 Data used for storing 
  #6 Notnull values of all the columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   credit.rating                   1000 non-null   int64
#  1   account.balance                 1000 non-null   int64
#  2   credit.duration.months          1000 non-null   int64
#  3   previous.credit.payment.status  1000 non-null   int64
#  4   credit.purpose                  1000 non-null   int64
#  5   credit.amount                   1000 non-null   int64
#  6   savings                         1000 non-null   int64
#  7   employment.duration             1000 non-null   int64
#  8   installment.rate                1000 non-null   int64
#  9   marital.status                  1000 non-null   int64
#  10  guarantor                       1000 non-null   int64
#  11  residence.duration              1000 non-null   int64
#  12  current.assets                  1000 non-null   int64
#  13  age                             1000 non-null   int64
#  14  other.credits                   1000 non-null   int64
#  15  apartment.type                  1000 non-null   int64
#  16  bank.credits                    1000 non-null   int64
#  17  occupation                      1000 non-null   int64
#  18  dependents                      1000 non-null   int64
#  19  telephone                       1000 non-null   int64
#  20  foreign.worker                  1000 non-null   int64
# dtypes: int64(21)
# memory usage: 164.2 KB

# %%
# checking the columns names 
df.columns
# Out:
# Index(['credit.rating', 'account.balance', 'credit.duration.months',
#        'previous.credit.payment.status', 'credit.purpose', 'credit.amount',
#        'savings', 'employment.duration', 'installment.rate', 'marital.status',
#        'guarantor', 'residence.duration', 'current.assets', 'age',
#        'other.credits', 'apartment.type', 'bank.credits', 'occupation',
#        'dependents', 'telephone', 'foreign.worker'],
#       dtype='object')

# %%
#replacing the space with underscore in columns names
df.columns = [col.replace(".", "_")for col in df.columns]

# %%
#verify...
df.columns
# Out:
# Index(['credit_rating', 'account_balance', 'credit_duration_months',
#        'previous_credit_payment_status', 'credit_purpose', 'credit_amount',
#        'savings', 'employment_duration', 'installment_rate', 'marital_status',
#        'guarantor', 'residence_duration', 'current_assets', 'age',
#        'other_credits', 'apartment_type', 'bank_credits', 'occupation',
#        'dependents', 'telephone', 'foreign_worker'],
#       dtype='object')

# %%
#checking the shape of data
df.shape
# Out:
# (1000, 21)

# %%
#Filtering the missing values 
#checking the null values in dataset using df.isnull() command 
#to_list  creates the list of the output of null values with the sum of nullvalues of every column
df.isnull().sum()
# Out:
# credit_rating                     0
# account_balance                   0
# credit_duration_months            0
# previous_credit_payment_status    0
# credit_purpose                    0
# credit_amount                     0
# savings                           0
# employment_duration               0
# installment_rate                  0
# marital_status                    0
# guarantor                         0
# residence_duration                0
# current_assets                    0
# age                               0
# other_credits                     0
# apartment_type                    0
# bank_credits                      0
# occupation                        0
# dependents                        0
# telephone                         0
# foreign_worker                    0
# dtype: int64

# %% [markdown]
# **Observations:**
#
#
# *   There are 1000rows and 21columns
# *   All the variables/columns are label encoded , so only numeric columns are seen
# *   Data cleaning is not required as there is no any null values
# *   Dependent variable is Credit rating.

# %%
#include all includes all datatype columns in dataset like object or float or int columns
#describe is used for getting every info of columns like
 #If the column datatype is object it shows all the unique values,topmost value,frequency of column
 #If the column datatype is number(float,int) it shows mean,median,standard deviation,quantile of every column
df.describe(include="all")
# Out:
#        credit_rating  account_balance  credit_duration_months  \
# count    1000.000000      1000.000000             1000.000000
# mean        0.700000         2.183000               20.903000
# std         0.458487         0.835589               12.058814
# min         0.000000         1.000000                4.000000
# 25%         0.000000         1.000000               12.000000
# 50%         1.000000         2.000000               18.000000
# 75%         1.000000         3.000000               24.000000
# max         1.000000         3.000000               72.000000
#
#        previous_credit_payment_status  credit_purpose  credit_amount  \
# count                     1000.000000     1000.000000     1000.00000
# mean                         2.292000        2.965000     3271.24800
# std                          0.620581        0.971967     2822.75176
# min                          1.000000        1.000000      250.00000
# 25%                          2.000000        2.000000     1365.50000
# 50%                          2.000000        3.000000     2319.50000
# 75%                          3.000000        4.000000     3972.25000
# max                          3.000000        4.000000    18424.00000
#
#            savings  employment_duration  installment_rate  marital_status  \
# count  1000.000000           1000.00000       1000.000000     1000.000000
# mean      1.874000              2.44600          2.973000        2.372000
# std       1.196476              1.10558          1.118715        1.067125
# min       1.000000              1.00000          1.000000        1.000000
# 25%       1.000000              2.00000          2.000000        1.000000
# 50%       1.000000              2.00000          3.000000        3.000000
# 75%       3.000000              4.00000          4.000000        3.000000
# max       4.000000              4.00000          4.000000        4.000000
#
#          guarantor  residence_duration  current_assets         age  \
# count  1000.000000         1000.000000     1000.000000  1000.00000
# mean      1.093000            2.845000        2.358000    35.54200
# std       0.290578            1.103718        1.050209    11.35267
# min       1.000000            1.000000        1.000000    19.00000
# 25%       1.000000            2.000000        1.000000    27.00000
# 50%       1.000000            3.000000        2.000000    33.00000
# 75%       1.000000            4.000000        3.000000    42.00000
# max       2.000000            4.000000        4.000000    75.00000
#
#        other_credits  apartment_type  bank_credits   occupation   dependents  \
# count    1000.000000     1000.000000   1000.000000  1000.000000  1000.000000
# mean        1.814000        1.928000      1.367000     2.904000     1.155000
# std         0.389301        0.530186      0.482228     0.653614     0.362086
# min         1.000000        1.000000      1.000000     1.000000     1.000000
# 25%         2.000000        2.000000      1.000000     3.000000     1.000000
# 50%         2.000000        2.000000      1.000000     3.000000     1.000000
# 75%         2.000000        2.000000      2.000000     3.000000     1.000000
# max         2.000000        3.000000      2.000000     4.000000     2.000000
#
#          telephone  foreign_worker
# count  1000.000000     1000.000000
# mean      1.404000        1.037000
# std       0.490943        0.188856
# min       1.000000        1.000000
# 25%       1.000000        1.000000
# 50%       1.000000        1.000000
# 75%       2.000000        1.000000
# max       2.000000        2.000000

# %%
#checking the datatype of all columns
df.dtypes
# Out:
# credit_rating                     int64
# account_balance                   int64
# credit_duration_months            int64
# previous_credit_payment_status    int64
# credit_purpose                    int64
# credit_amount                     int64
# savings                           int64
# employment_duration               int64
# installment_rate                  int64
# marital_status                    int64
# guarantor                         int64
# residence_duration                int64
# current_assets                    int64
# age                               int64
# other_credits                     int64
# apartment_type                    int64
# bank_credits                      int64
# occupation                        int64
# dependents                        int64
# telephone                         int64
# foreign_worker                    int64
# dtype: object

# %%
#selecting only numeric columns 
numeric_cols=df.select_dtypes(include=['int64', 'float64']).columns.tolist()
numeric_cols
# Out:
# ['credit_rating',
#  'account_balance',
#  'credit_duration_months',
#  'previous_credit_payment_status',
#  'credit_purpose',
#  'credit_amount',
#  'savings',
#  'employment_duration',
#  'installment_rate',
#  'marital_status',
#  'guarantor',
#  'residence_duration',
#  'current_assets',
#  'age',
#  'other_credits',
#  'apartment_type',
#  'bank_credits',
#  'occupation',
#  'dependents',
#  'telephone',
#  'foreign_worker']

# %%
#selecting only object columns
object_cols=df.select_dtypes(include=['object']).columns.tolist()
object_cols
# Out:
# []

# %%
#selecting the actual numerical columns with continous values
numeric_columns=["age","credit_amount"]
numeric_columns
#remaining column are label encoded with values(type of dummies)
# Out:
# ['age', 'credit_amount']

# %% [markdown]
# **Uniques of every columns:**

# %%
df.credit_rating.unique()
# Out:
# array([1, 0])

# %%
df.account_balance.unique()
# Out:
# array([1, 2, 3])

# %%
df.credit_duration_months.unique()
# Out:
# array([18,  9, 12, 10,  8,  6, 24, 11, 30, 48, 36, 15, 42, 21, 27, 33, 28,
#         4, 47, 14, 39, 60,  5, 22, 54, 13, 16,  7, 20, 26, 45, 72, 40])

# %%
df.previous_credit_payment_status.unique()
# Out:
# array([3, 2, 1])

# %%
df.credit_purpose.unique()
# Out:
# array([2, 4, 3, 1])

# %%
df.credit_amount.unique()
# Out:
# array([ 1049,  2799,   841,  2122,  2171,  2241,  3398,  1361,  1098,
#         3758,  3905,  6187,  1957,  7582,  1936,  2647,  3939,  3213,
#         2337,  7228,  3676,  3124,  2384,  1424,  4716,  4771,   652,
#         1154,  3556,  4796,  3017,  3535,  6614,  1376,  1721,   860,
#         1495,  1934,  3378,  3868,   996,  1755,  1028,  2825,  1239,
#         1216,  1258,  1864,  1474,  1382,   640,  3919,  1224,  2331,
#         6313,   385,  1655,  1053,  3160,  3079,  1163,  2679,  3578,
#        10875,  1344,  1237,  3077,  2284,  1567,  2032,  2745,  1867,
#         2299,   929,  3399,  2030,  3275,  1940,  1602,  1979,  2022,
#         3342,  5866,  2360,  1520,  3651,  2346,  4454,   666,  1965,
#         1995,  2991,  4221,  1364,  6361,  4526,  3573,  4455,  2136,
#         5954,  3777,   806,  4712,  7432,  1851,  1393,  1412,  1473,
#         1533,  2012,  3959,   428,  2366,   763,  3976,  6260,  1919,
#         2603,   936,  3062,  4795,  5842,  2063,  1459,  1213,  5103,
#          874,  2978,  1820,  2872,  1925,  2515,  2116,  1453,  1543,
#         1318,  2325,   932,  3148,  3835,  3832,  5084,  2406,  2394,
#         2476,  2964,  1262,  1542,  1743,   409,  8858,  3512,  1158,
#         2684,  1498,  6416,  3617,  1291,  1275,  3972,  3343,   392,
#         2134,  5771,  2788,  5848,  1228,  1297,  1552,  1963,  3235,
#         4139,  1804,  1950, 12749,  1236,  1055,  8072,  2831,  1449,
# array([1, 2, 3, 4])

# %%
df.installment_rate.unique()
# Out:
# array([4, 2, 3, 1])

# %%
df.marital_status.unique()
# Out:
# array([1, 3, 4])

# %%
df.guarantor.unique()
# Out:
# array([1, 2])

# %%
df.residence_duration.unique()
# Out:
# array([4, 2, 3, 1])

# %%
df.current_assets.unique()
# Out:
# array([2, 1, 3, 4])

# %%
df.age.unique()
# Out:
# array([21, 36, 23, 39, 38, 48, 40, 65, 24, 31, 44, 25, 37, 49, 33, 26, 51,
#        29, 56, 47, 34, 28, 41, 58, 61, 30, 63, 27, 45, 43, 52, 22, 60, 32,
#        35, 42, 59, 54, 64, 46, 74, 50, 20, 55, 53, 19, 57, 66, 68, 70, 67,
#        75, 62])

# %%
df.guarantor.unique()
# Out:
# array([1, 2])

# %%
df.apartment_type.unique()
# Out:
# array([1, 2, 3])

# %%
df.bank_credits.unique()
# Out:
# array([1, 2])

# %%
df.occupation.unique()
# Out:
# array([3, 2, 1, 4])

# %%
df.dependents.unique()
# Out:
# array([1, 2])

# %%
df.telephone.unique()
# Out:
# array([1, 2])

# %%
df.foreign_worker.unique()
# Out:
# array([1, 2])

# %% [markdown]
# **Univariate Analysis:**

# %%
sns.distplot(df.age)

# %%
sns.distplot(df.credit_amount)

# %%
sns.distplot(df.credit_duration_months)

# %%
sns.countplot(df.credit_rating,data=df,palette = "rainbow")
plt.show()

# %%
sns.countplot(df.account_balance,data=df,palette = "rainbow")
plt.show()

# %%
sns.distplot(df.credit_duration_months)

# %%
sns.countplot(df.previous_credit_payment_status,data=df,palette = "rainbow")
plt.show()

# %%
sns.countplot(df.credit_purpose,data=df,palette = "rainbow")
plt.show()

# %%
sns.countplot(df.savings,data=df,palette = "rainbow")
plt.show()

# %%
sns.countplot(df.employment_duration,data=df,palette = "rainbow")
plt.show()

# %%
sns.countplot(df.installment_rate,data=df,palette = "rainbow")
plt.show()

# %%
sns.countplot(df.marital_status,data=df,palette = "rainbow")
plt.show()

# %%
sns.countplot(df.guarantor,data=df,palette = "rainbow")
plt.show()

# %%
sns.countplot(df.residence_duration,data=df,palette = "rainbow")
plt.show()

# %%
sns.countplot(df.current_assets,data=df,palette = "rainbow")
plt.show()

# %%
sns.countplot(df.other_credits,data=df,palette = "rainbow")
plt.show()

# %%
sns.countplot(df.apartment_type,data=df,palette = "rainbow")
plt.show()

# %%
sns.countplot(df.bank_credits,data=df,palette = "rainbow")
plt.show()

# %%
sns.countplot(df.occupation,data=df,palette = "rainbow")
plt.show()

# %%
sns.countplot(df.dependents,data=df,palette = "rainbow")
plt.show()

# %%
sns.countplot(df.telephone,data=df,palette = "rainbow")
plt.show()

# %%
sns.countplot(df.foreign_worker,data=df,palette = "rainbow")
plt.show()

# %% [markdown]
# **Bivariate_Analysis:**

# %%
sns.countplot(df.credit_rating,hue=df.account_balance)

# %%
sns.countplot(df.credit_rating,hue=df.credit_purpose)

# %%
sns.countplot(df.credit_rating,hue=df.previous_credit_payment_status)

# %%
sns.countplot(df.credit_rating,hue=df.savings)

# %%
sns.countplot(df.credit_rating,hue=df.employment_duration)

# %%
sns.countplot(df.credit_rating,hue=df.installment_rate)

# %%
sns.countplot(df.credit_rating,hue=df.marital_status)

# %%
sns.countplot(df.credit_rating,hue=df.guarantor)

# %%
sns.countplot(df.credit_rating,hue=df.residence_duration)

# %%
sns.countplot(df.credit_rating,hue=df.current_assets)

# %%
sns.countplot(df.credit_rating,hue=df.other_credits)

# %%
sns.countplot(df.credit_rating,hue=df.apartment_type)

# %%
sns.countplot(df.credit_rating,hue=df.bank_credits)

# %%
sns.countplot(df.credit_rating,hue=df.occupation)

# %%
sns.countplot(df.credit_rating,hue=df.telephone)

# %%
sns.countplot(df.credit_rating,hue=df.foreign_worker)

# %%
sns.boxplot(y =df.age , x = df.credit_rating )

# %%
sns.boxplot(y = df.credit_amount , x = df.credit_rating )

# %%
sns.boxplot(y = df.credit_duration_months , x = df.credit_rating )

# %% [markdown]
# **Multivariate Analysis::**

# %%
#correlation of every columns
#diagonal value will be always eqaul to 1 bcz correlation of its own value is always 1.
df.corr()
# Out:
#                                 credit_rating  account_balance  \
# credit_rating                        1.000000         0.339409
# account_balance                      0.339409         1.000000
# credit_duration_months              -0.214927        -0.071254
# previous_credit_payment_status       0.220233         0.180614
# credit_purpose                      -0.106696        -0.009361
# credit_amount                       -0.128540        -0.040345
# savings                              0.179191         0.228340
# employment_duration                  0.118092         0.081681
# installment_rate                    -0.072404        -0.022551
# marital_status                       0.091249         0.034715
# guarantor                           -0.000751        -0.119636
# residence_duration                  -0.002967        -0.064727
# current_assets                      -0.142612        -0.030244
# age                                  0.091967         0.054990
# other_credits                        0.113285         0.049352
# apartment_type                       0.018119         0.029771
# bank_credits                         0.045727         0.074127
# occupation                          -0.032735         0.030366
# dependents                           0.003015        -0.027676
# telephone                            0.036466         0.063609
# foreign_worker                       0.082079        -0.036607
#
#                                 credit_duration_months  \
# credit_rating                                -0.214927
# account_balance                              -0.071254
# credit_duration_months                        1.000000
# previous_credit_payment_status               -0.041958
# credit_purpose                               -0.059048
# credit_amount                                 0.647866
# savings                                       0.048550
# employment_duration                           0.061587
# installment_rate                              0.074749
# marital_status                                0.045124
# guarantor                                    -0.009993
# residence_duration                            0.034067
# current_assets                                0.303971
# age                                          -0.032809
# other_credits                                -0.077411
# apartment_type                                0.153126
# bank_credits                                  0.011292
# occupation                                    0.210910
# dependents                                   -0.023834
# telephone                                     0.164718
# foreign_worker                               -0.134680
#
#                                 previous_credit_payment_status  \
# credit_rating                                         0.220233
# account_balance                                       0.180614
# credit_duration_months                               -0.041958
# previous_credit_payment_status                        1.000000
# credit_purpose                                       -0.017890
# credit_amount                                        -0.002558
# savings                                               0.023986
# employment_duration                                   0.138263
# installment_rate                                      0.030111
# marital_status                                        0.071611
# guarantor                                            -0.056376
# residence_duration                                    0.045684
# current_assets                                       -0.051508
# age                                                   0.131749
# other_credits                                         0.179456
# apartment_type                                        0.057877
# bank_credits                                          0.461048
# occupation                                            0.029693
# dependents                                            0.007751
# telephone                                             0.059245
# foreign_worker                                        0.018756
#
#                                 credit_purpose  credit_amount   savings  \
# credit_rating                        -0.106696      -0.128540  0.179191
# account_balance                      -0.009361      -0.040345  0.228340
# credit_duration_months               -0.059048       0.647866  0.048550
# previous_credit_payment_status       -0.017890      -0.002558  0.023986
# credit_purpose                        1.000000      -0.169606 -0.034783
# credit_amount                        -0.169606       1.000000  0.071399
# savings                              -0.034783       0.071399  1.000000
# employment_duration                  -0.002226       0.010695  0.129549
# installment_rate                      0.057127      -0.291226  0.016900
# marital_status                        0.043448       0.034663  0.031260
# guarantor                             0.022169      -0.000227 -0.104462
# residence_duration                   -0.064780       0.031131  0.095107
# current_assets                       -0.101466       0.316100  0.028765
# age                                   0.054382       0.024868  0.083651
# other_credits                        -0.059549      -0.075145  0.001212
# apartment_type                        0.016472       0.125360  0.004620
# bank_credits                          0.070146       0.047072 -0.025604
# occupation                           -0.150255       0.291749  0.008837
# dependents                            0.046717       0.036129  0.026641
# telephone                            -0.041661       0.266845  0.085042
# foreign_worker                        0.067047      -0.048033  0.007363
#
#                                 employment_duration  installment_rate  \
# credit_rating                              0.118092         -0.072404
# account_balance                            0.081681         -0.022551
# credit_duration_months                     0.061587          0.074749
# previous_credit_payment_status             0.138263          0.030111
# credit_purpose                            -0.002226          0.057127
# credit_amount                              0.010695         -0.291226
# savings                                    0.129549          0.016900
# employment_duration                        1.000000          0.127099
# installment_rate                           0.127099          1.000000
# marital_status                             0.166372          0.116588
# guarantor                                 -0.020185         -0.013823
# residence_duration                         0.275736          0.049302
# current_assets                             0.115811          0.053391
# age                                        0.316933          0.063105
# other_credits                              0.009201          0.002248
# apartment_type                             0.143640          0.091229
# bank_credits                               0.139536          0.027664
# occupation                                 0.118875          0.097755
# dependents                                 0.097196         -0.071207
# telephone                                  0.084495          0.014413
# foreign_worker                            -0.031172         -0.094762
#
#                                 marital_status  guarantor  residence_duration  \
# credit_rating                         0.091249  -0.000751           -0.002967
# account_balance                       0.034715  -0.119636           -0.064727
# credit_duration_months                0.045124  -0.009993            0.034067
# previous_credit_payment_status        0.071611  -0.056376            0.045684
# credit_purpose                        0.043448   0.022169           -0.064780
# credit_amount                         0.034663  -0.000227            0.031131
# savings                               0.031260  -0.104462            0.095107
# employment_duration                   0.166372  -0.020185            0.275736
# installment_rate                      0.116588  -0.013823            0.049302
# marital_status                        1.000000   0.036814           -0.024086
# guarantor                             0.036814   1.000000           -0.020553
# residence_duration                   -0.024086  -0.020553            1.000000
# current_assets                        0.017707  -0.119051            0.147231
# age                                   0.075013  -0.029001            0.268627
# other_credits                        -0.035680  -0.015061            0.035341
# apartment_type                        0.160620  -0.066950            0.009990
# bank_credits                          0.076789  -0.008079            0.059967
# occupation                            0.022549  -0.042543            0.012655
# dependents                            0.169273   0.005566            0.042643
# telephone                             0.051038  -0.067165            0.095359
# foreign_worker                        0.080643   0.137881           -0.039691
#
#                                 current_assets       age  other_credits  \
# credit_rating                        -0.142612  0.091967       0.113285
# account_balance                      -0.030244  0.054990       0.049352
# credit_duration_months                0.303971 -0.032809      -0.077411
# previous_credit_payment_status       -0.051508  0.131749       0.179456
# credit_purpose                       -0.101466  0.054382      -0.059549
# credit_amount                         0.316100  0.024868      -0.075145
# savings                               0.028765  0.083651       0.001212
# employment_duration                   0.115811  0.316933       0.009201
# installment_rate                      0.053391  0.063105       0.002248
# marital_status                        0.017707  0.075013      -0.035680
# guarantor                            -0.119051 -0.029001      -0.015061
# residence_duration                    0.147231  0.268627       0.035341
# current_assets                        1.000000  0.075860      -0.098943
# age                                   0.075860  1.000000      -0.024799
# other_credits                        -0.098943 -0.024799       1.000000
# apartment_type                        0.342969  0.304654      -0.098896
# bank_credits                         -0.002739  0.110979      -0.046592
# occupation                            0.276149  0.013010      -0.007301
# dependents                            0.011872  0.120312      -0.072220
# telephone                             0.196802  0.142559      -0.035908
# foreign_worker                       -0.132462  0.011415       0.012008
#
#                                 apartment_type  bank_credits  occupation  \
# credit_rating                         0.018119      0.045727   -0.032735
# account_balance                       0.029771      0.074127    0.030366
# credit_duration_months                0.153126      0.011292    0.210910
# previous_credit_payment_status        0.057877      0.461048    0.029693
# credit_purpose                        0.016472      0.070146   -0.150255
# credit_amount                         0.125360      0.047072    0.291749
# savings                               0.004620     -0.025604    0.008837
# employment_duration                   0.143640      0.139536    0.118875
# installment_rate                      0.091229      0.027664    0.097755
# marital_status                        0.160620      0.076789    0.022549
# guarantor                            -0.066950     -0.008079   -0.042543
# residence_duration                    0.009990      0.059967    0.012655
# current_assets                        0.342969     -0.002739    0.276149
# age                                   0.304654      0.110979    0.013010
# other_credits                        -0.098896     -0.046592   -0.007301
# apartment_type                        1.000000      0.032982    0.104243
# bank_credits                          0.032982      1.000000   -0.011967
# occupation                            0.104243     -0.011967    1.000000
# dependents                            0.115549      0.086652   -0.093559
# telephone                             0.100327      0.041148    0.383022
# foreign_worker                       -0.083336     -0.017355   -0.092835
#
#                                 dependents  telephone  foreign_worker
# credit_rating                     0.003015   0.036466        0.082079
# account_balance                  -0.027676   0.063609       -0.036607
# credit_duration_months           -0.023834   0.164718       -0.134680
# previous_credit_payment_status    0.007751   0.059245        0.018756
# credit_purpose                    0.046717  -0.041661        0.067047
# credit_amount                     0.036129   0.266845       -0.048033
# savings                           0.026641   0.085042        0.007363
# employment_duration               0.097196   0.084495       -0.031172
# installment_rate                 -0.071207   0.014413       -0.094762
# marital_status                    0.169273   0.051038        0.080643
# guarantor                         0.005566  -0.067165        0.137881
# residence_duration                0.042643   0.095359       -0.039691
# current_assets                    0.011872   0.196802       -0.132462
# age                               0.120312   0.142559        0.011415
# other_credits                    -0.072220  -0.035908        0.012008
# apartment_type                    0.115549   0.100327       -0.083336
# bank_credits                      0.086652   0.041148       -0.017355
# occupation                       -0.093559   0.383022       -0.092835
# dependents                        1.000000  -0.014753        0.077071
# telephone                        -0.014753   1.000000       -0.075012
# foreign_worker                    0.077071  -0.075012        1.000000

# %%
#correlation map
f,ax = plt.subplots(figsize=(18, 18))
sns.heatmap(df.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)

# %%
#let us write a function that will help us create boxplot and histogram for any input numerical variable
#this function takes numerical column as input and return boxplots and histogram for the variable

def histogram_boxplot(feature,figsize=(15,10),bins=None):
  """ Boxplot and histogram combined 
  feature :1-d feature array
  figsize:size of fig (default(9,8))
  bins: number of bins (default None/auto)
  """
  sns.set(font_scale=2) #setting the font scale of the seaborn
  f2,(ax_box2,ax_hist2)=plt.subplots(nrows=2, #number of rows of the subplot grid=2
                                     sharex=True, #x axis will be shared among all subplots
                                     gridspec_kw={"height_ratios":(0.25,0.75)},
                                     figsize=figsize
                                     ) #creating the 2 subplots
  sns.boxplot(feature,ax=ax_box2,showmeans=True,color="red") #box plot will be created and a star
  sns.distplot(feature,kde=False,ax=ax_hist2,bins=bins) if bins else sns.distplot(feature,kde=False,ax=ax_hist2)

  ax_hist2.axvline(np.mean(feature),color="g",linestyle="--") #add mean to the histogram
  ax_hist2.axvline(np.median(feature),color="black",linestyle="-") #add median to the histogram

# %%
#plotting histogram boxplot of every numeric columns in one for loop 
for feature in numeric_columns:
  histogram_boxplot(df[feature],figsize=(15,10),bins=None)
  plt.show()

# %%
#selecting only categorical columns for barplot
numeric_cols.remove('age')
numeric_cols.remove('credit_amount')

# %%
#Drawing all barplots for categorical columns

for features in numeric_cols:
  df[features].value_counts().plot.bar()
  plt.xlabel(features)
  plt.ylabel("count")
  plt.show()

# %%
#verify
#Outliers Detection Using Box Plot
# to plot the box plot of all the columns to find the outhliers
plt.figure(figsize=(15,30))
for i , variable in enumerate(numeric_columns):
                      plt.subplot(9,3,i+1)
                      plt.boxplot(df[variable],whis=1.5)
                      plt.tight_layout()
                      plt.title(variable)
plt.show()

# %%
#outliers treatment 
#clipping method is used for outliers treatment 
#In the given code below first it gets q1,q3 and IQR of every column and clipping process is done for outliers treatment
#for outliers treatment we can use np.clip and np.where for cliiping purpose 
for feature in numeric_columns :
  Q1=df[feature].quantile(0.25)
  Q3=df[feature].quantile(0.75)
  IQR=Q3-Q1
  Upper_whisker=Q3+1.5*IQR
  Lower_whisker=Q1-1.5*IQR
  df[feature] = np.where(df[feature] <Lower_whisker,Lower_whisker ,df[feature])
  df[feature] = np.where(df[feature] >Upper_whisker, Upper_whisker,df[feature])

# %%
#verify
#Outliers Detection Using Box Plot
# to plot the box plot of all the columns to find the outhliers
plt.figure(figsize=(15,30))
for i , variable in enumerate(numeric_columns):
                      plt.subplot(9,3,i+1)
                      plt.boxplot(df[variable],whis=1.5)
                      plt.tight_layout()
                      plt.title(variable)
plt.show()

# %% [markdown]
# **Splitting the data into dependent and independent variables:**

# %%
#split the dependent and independent variable 
x = df.drop(['credit_rating'], axis=1)
y = df[['credit_rating']]

print(x.head())
print(y.head())
# Out:
#    account_balance  credit_duration_months  previous_credit_payment_status  \
# 0                1                      18                               3
# 1                1                       9                               3
# 2                2                      12                               2
# 3                1                      12                               3
# 4                1                      12                               3
#
#    credit_purpose  credit_amount  savings  employment_duration  \
# 0               2         1049.0        1                    1
# 1               4         2799.0        1                    2
# 2               4          841.0        2                    3
# 3               4         2122.0        1                    2
# 4               4         2171.0        1                    2
#
#    installment_rate  marital_status  guarantor  residence_duration  \
# 0                 4               1          1                   4
# 1                 2               3          1                   2
# 2                 2               1          1                   4
# 3                 3               3          1                   2
# 4                 4               3          1                   4
#
#    current_assets   age  other_credits  apartment_type  bank_credits  \
# 0               2  21.0              2               1             1
# 1               1  36.0              2               1             2
# 2               1  23.0              2               1             1
# 3               1  39.0              2               1             2
# 4               2  38.0              1               2             2
#
#    occupation  dependents  telephone  foreign_worker
# 0           3           1          1               1
# 1           3           2          1               1
# 2           2           1          1               1
# 3           2           2          1               2
# 4           2           1          1               2
#    credit_rating
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %% [markdown]
# **Model Building/selecting model:**

# %%
#import required libraries
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state = 10)

# %%
#checking the shape of splited data
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (800, 20) (200, 20) (800, 1) (200, 1)

# %%
#import confusion matrix code 
#cnfusion matrix creates crosstab of TN,TP,FP,FN
from sklearn.metrics import confusion_matrix

# %%
# defining a confusion matrix

def make_confusion_matrix(y_actual,y_predict,labels=[1,0]):
  '''
  y_predict : prediction of class
  y_actual : ground truth 
  '''
  cm =confusion_matrix(y_actual,y_predict,labels=[1,0])
  df_cm = pd.DataFrame(cm,index=[i for i in ["Provide Disc","No Disc"]],
                       columns=[i for i in ["Provide Disc","No Disc"]])
  group_counts = ["{0:0.0f}".format(value) for value in cm.flatten()]
  group_percentages = ["{0:.2%}".format(value) for value in cm.flatten()/np.sum(cm)]
  labels = [f"{v1}\n{v2}" for v1,v2 in
            zip(group_counts,group_percentages)]
  labels = np.asarray(labels).reshape(2,2)
  plt.figure(figsize = (10,7))
  sns.heatmap(df_cm,annot=labels,fmt='')
  plt.ylabel("True label")
  plt.xlabel("Predicted label")

# %%
#choose the model and analyze
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()

# %%
#fitting the model from x,y train set
logreg.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
#predict the test set
pred_test = logreg.predict(x_test)

# %%
#predict the train set
pred_train = logreg.predict(x_train)

# %%
#calling the confusion matrix for train data 
make_confusion_matrix(y_train,pred_train)

# %%
#for test data call confusion matrix
make_confusion_matrix(y_test,pred_test)

# %%
#import required finding values
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score

# %%
print("Accuracy on train data:",accuracy_score(y_train,pred_train))
print("Accuracy on test data:",accuracy_score(y_test,pred_test))
print("\n")
print("Recall on train data:",recall_score(y_train,pred_train))
print("Recall on test data:",recall_score(y_test,pred_test))
print("\n")
print("Precision on train data:",precision_score(y_train,pred_train))
print("Precision on test data:",precision_score(y_test,pred_test))
print("\n")
print("f1 on train data:",f1_score(y_train,pred_train))
print("f1 on test data:",f1_score(y_test,pred_test))
print("\n")
# Out:
# Accuracy on train data: 0.77875
# Accuracy on test data: 0.755
#
#
# Recall on train data: 0.9065255731922398
# Recall on test data: 0.9022556390977443
#
#
# Precision on train data: 0.8056426332288401
# Precision on test data: 0.7692307692307693
#
#
# f1 on train data: 0.8531120331950207
# f1 on test data: 0.8304498269896194

# %%
from sklearn.metrics import roc_auc_score,roc_curve

# %%
#plotting the roc curve and getting the value of auc 
logit_roc_auc=roc_auc_score(y_test,logreg.predict_proba(x_test)[:,1])
fpr,tpr,thresholds=roc_curve(y_test,logreg.predict_proba(x_test)[:,1])
plt.figure(figsize=(13,8))
plt.plot(fpr,tpr,label="Logistic_regression (area=%0.2f)"% logit_roc_auc)
plt.plot([0,1],[0,1],"r--")
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.xlabel("False positive rate(fpr)")
plt.ylabel("True positive rate(tpr)")
plt.title("ROC")
plt.legend(loc="lower right")
plt.savefig("Log_ROC")
plt.show()

# %%
#probaility of train set for predicted value
train_pred_prob = logreg.predict_proba(x_train)[:,1]
train_pred_prob
# Out:
# array([0.52861282, 0.84212698, 0.93309798, 0.26456525, 0.52002867,
#        0.93950528, 0.46361959, 0.87953682, 0.590554  , 0.74411695,
#        0.82065181, 0.37753194, 0.20933692, 0.50967939, 0.93188057,
#        0.52244098, 0.39442152, 0.33347978, 0.49747761, 0.29589844,
#        0.66571706, 0.3444127 , 0.8852285 , 0.84508699, 0.72419044,
#        0.75377711, 0.83075158, 0.74050897, 0.54190622, 0.91992889,
#        0.4845382 , 0.31852702, 0.9058829 , 0.95546045, 0.87193935,
#        0.94777299, 0.72280857, 0.48449323, 0.98488743, 0.73635768,
#        0.23730862, 0.73179662, 0.8641965 , 0.95511023, 0.55793187,
#        0.4927433 , 0.96526714, 0.75663125, 0.82762501, 0.80769048,
#        0.88150174, 0.61349185, 0.70298697, 0.71687031, 0.93753558,
#        0.95941234, 0.93110615, 0.90907943, 0.9534318 , 0.45196787,
#        0.84868173, 0.95063319, 0.66192592, 0.74254853, 0.75036928,
#        0.55953448, 0.94152426, 0.85421323, 0.89198883, 0.87207434,
#        0.88618437, 0.94858973, 0.90179453, 0.90456185, 0.94826601,
#        0.81123193, 0.88320543, 0.74644288, 0.65398366, 0.9840705 ,
#        0.20180019, 0.55015087, 0.30288542, 0.89401998, 0.78944431,
#        0.48112835, 0.84605546, 0.2176875 , 0.27868327, 0.77430842,
#        0.63395766, 0.49269294, 0.73674639, 0.45192805, 0.69100989,
#        0.95966471, 0.44043393, 0.8020179 , 0.9503069 , 0.86645001,
#        0.71565547, 0.62890099, 0.82855493, 0.57660767, 0.46521382,
#        0.96386195, 0.70903098, 0.98191421, 0.57900757, 0.62754484,
#        0.72013401, 0.67518193, 0.340712  , 0.97987876, 0.87167738,
#        0.8722533 , 0.88496896, 0.87217205, 0.15460165, 0.92111   ,
#        0.89494313, 0.48734046, 0.80917936, 0.9112258 , 0.84649543,
#        0.42606555, 0.90603904, 0.75891022, 0.98850407, 0.9773685 ,
#        0.7254001 , 0.78276627, 0.69337007, 0.60066943, 0.95315834,
#        0.19896557, 0.97995607, 0.75081642, 0.84199453, 0.90079433,
#        0.75399053, 0.94044758, 0.38381378, 0.90079764, 0.74137015,
#        0.86961273, 0.88585255, 0.55554801, 0.73678611, 0.83467861,
#        0.70585594, 0.68140464, 0.83580021, 0.51172668, 0.63406909,
#        0.26351248, 0.60932942, 0.88043187, 0.24940903, 0.79165159,
#        0.88885099, 0.87276592, 0.60154728, 0.59720303, 0.3681194 ,
#        0.63288322, 0.26646573, 0.56287078, 0.80696387, 0.93335764,
#        0.67051614, 0.39027986, 0.77010218, 0.9172389 , 0.77241415,
#        0.92895661, 0.85482239, 0.29867456, 0.58425862, 0.48607572,
#        0.82132697, 0.38563312, 0.63355951, 0.95140438, 0.21181471,
#        0.96926518, 0.35803131, 0.77039979, 0.68550285, 0.96686079,
Cutoff_prob=np.arange(0,1.01,0.01)

for cutoff in Cutoff_prob:
  y_train["pred_y"]=(train_pred_prob > cutoff).astype("int64")
  TP =np.logical_and((y_train.pred_y ==1),(y_train.credit_rating ==1)).sum()
  FN =np.logical_and((y_train.pred_y ==0),(y_train.credit_rating ==1)).sum()
  TN =np.logical_and((y_train.pred_y ==0),(y_train.credit_rating ==0)).sum()
  FP =np.logical_and((y_train.pred_y ==1),(y_train.credit_rating ==0)).sum()
  P =TP + FN
  N =TN + FP
  temp_data={"Cutoff_Prob":cutoff,
             "TP":TP,
             "FN":FN,
             "TN":TN,
             "FP":FP,
             "P":P,
             "N":N}

  cutoff_data =cutoff_data.append(temp_data,ignore_index=True)   

  y_train.drop("pred_y",axis =1 ,inplace=True)

# %%
#values of sn,sp,ks,dist cutoffs,re,pr,f1,tpr,fpr
cutoff_data['Sn'] =cutoff_data["TP"]/cutoff_data["P"]
cutoff_data['Sp'] =cutoff_data["TN"]/cutoff_data["N"]
cutoff_data["Dist"]=((1-cutoff_data["Sn"])*2 + (1-cutoff_data["Sp"])*2) **0.5
cutoff_data["KS"]=((cutoff_data["TP"]/cutoff_data["P"]) - (cutoff_data["FP"]/cutoff_data["N"])).abs()
cutoff_data['Re'] =cutoff_data["TP"]/cutoff_data["P"]
cutoff_data['Pr'] =cutoff_data["TP"]/(cutoff_data["TP"]+cutoff_data["FP"])
cutoff_data['tpr'] =cutoff_data["Re"]
cutoff_data['fpr'] =1 - cutoff_data["Sp"]
cutoff_data["f1"]=2 * (cutoff_data["Pr"] * cutoff_data["Re"])/(cutoff_data["Pr"] +cutoff_data["Re"])

# %%
#selecting the required cutoff values for separating the 1's and 0's
dist_cutoffs = cutoff_data["Dist"].min()
ks_cutoffs = cutoff_data["KS"].max()
f1_cutoffs = cutoff_data["f1"].max()

# %%
#verify the values
cutoff_data.head()
# Out:
#    Cutoff_prob     TP   FN   TN     FP      P      N  Cutoff_Prob   Sn   Sp  \
# 0          NaN  567.0  0.0  0.0  233.0  567.0  233.0         0.00  1.0  0.0
# 1          NaN  567.0  0.0  0.0  233.0  567.0  233.0         0.01  1.0  0.0
# 2          NaN  567.0  0.0  0.0  233.0  567.0  233.0         0.02  1.0  0.0
# 3          NaN  567.0  0.0  0.0  233.0  567.0  233.0         0.03  1.0  0.0
# 4          NaN  567.0  0.0  0.0  233.0  567.0  233.0         0.04  1.0  0.0
#
#        Dist   KS   Re       Pr  tpr  fpr        f1
# 0  1.414214  0.0  1.0  0.70875  1.0  1.0  0.829554
# 1  1.414214  0.0  1.0  0.70875  1.0  1.0  0.829554
# 2  1.414214  0.0  1.0  0.70875  1.0  1.0  0.829554
# 3  1.414214  0.0  1.0  0.70875  1.0  1.0  0.829554
# 4  1.414214  0.0  1.0  0.70875  1.0  1.0  0.829554

# %%
#getting the values of accuracy,recall,precision,f1 scores from the cutoff values.
cutoffs = [dist_cutoffs,ks_cutoffs,f1_cutoffs]
for cutoff in cutoffs:
  y_pred_train = (logreg.predict_proba(x_train)[:,1]> cutoff).astype(int)
  y_pred_test = (logreg.predict_proba(x_test)[:,1]> cutoff).astype(int)
  print("using the cutoff value as : ",cutoff)
  print("Accuracy on train data :", accuracy_score(y_train,y_pred_train))
  print("Accuracy on test data :",accuracy_score(y_test,y_pred_test))
  print("Recall on train data:", recall_score(y_train, y_pred_train))
  print("Recall on test data:", recall_score(y_test, y_pred_test))
  print("Precision on train data:", precision_score(y_train, y_pred_train))
  print("Precision on test data:", precision_score(y_test, y_pred_test))
  print("f1 score on train data :",f1_score(y_train,y_pred_train))
  print("f1 score on test data :",f1_score(y_test,y_pred_test))
  print("\n")
# Out:
# using the cutoff value as :  1.0038265759114644
# Accuracy on train data : 0.29125
# Accuracy on test data : 0.335
# Recall on train data: 0.0
# Recall on test data: 0.0
# Precision on train data: 0.0
# Precision on test data: 0.0
# f1 score on train data : 0.0
# f1 score on test data : 0.0
#
#
# using the cutoff value as :  0.4961661027469325
# Accuracy on train data : 0.78
# Accuracy on test data : 0.755
# Recall on train data: 0.9118165784832452
# Recall on test data: 0.9022556390977443
# Precision on train data: 0.8040435458786936
# Precision on test data: 0.7692307692307693
# f1 score on train data : 0.8545454545454547
# f1 score on test data : 0.8304498269896194
#
#
# using the cutoff value as :  0.8578352180936996
# Accuracy on train data : 0.58
# Accuracy on test data : 0.575
# Recall on train data: 0.4479717813051146
# Recall on test data: 0.41353383458646614
# Precision on train data: 0.9169675090252708
# Precision on test data: 0.8870967741935484
# f1 score on train data : 0.6018957345971564
# f1 score on test data : 0.5641025641025641

# %% [markdown]
# **Conclusions:**

# %% [markdown]
# **Model Building using Decision Tree algorithm:**

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
#import required libraries
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state = 7)

# %%
model=DecisionTreeClassifier(criterion='gini',random_state=10)

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=10)

# %%
#predict the test set
pred_test = model.predict(x_test)

# %%
#predict trian set
pred_train=model.predict(x_train)

# %%
model.feature_importances_.sum()
# Out:
# 1.0000000000000002

# %%
model.feature_importances_
# Out:
# array([0.13420311, 0.08634671, 0.0369024 , 0.03366237, 0.15179222,
#        0.0331672 , 0.05819077, 0.07501145, 0.02059428, 0.        ,
#        0.04222805, 0.0677389 , 0.11481029, 0.00183766, 0.02961746,
#        0.04448517, 0.01956073, 0.02145012, 0.0224541 , 0.00594701])

# %%
#import confusion matrix code 
#cnfusion matrix creates crosstab of TN,TP,FP,FN
from sklearn.metrics import confusion_matrix

# %%
# defining a confusion matrix

def make_confusion_matrix(y_actual,y_predict,labels=[1,0]):
  '''
  y_predict : prediction of class
  y_actual : ground truth 
  '''
  cm =confusion_matrix(y_actual,y_predict,labels=[1,0])
  df_cm = pd.DataFrame(cm,index=[i for i in ["Provide Disc","No Disc"]],
                       columns=[i for i in ["Provide Disc","No Disc"]])
  group_counts = ["{0:0.0f}".format(value) for value in cm.flatten()]
  group_percentages = ["{0:.2%}".format(value) for value in cm.flatten()/np.sum(cm)]
  labels = [f"{v1}\n{v2}" for v1,v2 in
            zip(group_counts,group_percentages)]
  labels = np.asarray(labels).reshape(2,2)
  plt.figure(figsize = (10,7))
  sns.heatmap(df_cm,annot=labels,fmt='')
  plt.ylabel("True label")
  plt.xlabel("Predicted label")

# %%
#calling the confusion matrix for train data 
make_confusion_matrix(y_train,pred_train)

# %%
#calling the confusion matrix for test data 
make_confusion_matrix(y_test,pred_test)

# %%
#import required finding values
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score

# %%
print("Recall on train data:",recall_score(y_train,pred_train))
print("Recall on test data:",recall_score(y_test,pred_test))
print("\n")
# Out:
# Recall on train data: 1.0
# Recall on test data: 0.7832512315270936

# %%
print("Precision on train data:",precision_score(y_train,pred_train))
print("Precision on test data:",precision_score(y_test,pred_test))
print("\n")
# Out:
# Precision on train data: 1.0
# Precision on test data: 0.7718446601941747

# %%
from sklearn import tree
feature_names=list(x.columns)
plt.figure(figsize=(20,30))
out =tree.plot_tree(model,feature_names=feature_names,filled=True,fontsize=9,node_ids=False,class_names=None)

for o in out:
  arrow =o.arrow_patch
  if arrow is not None:
    arrow.set_edgecolor('black')
    arrow.set_linewidth(1)
plt.show()

# %%
#importance of features
print(pd.DataFrame(model.feature_importances_,columns=["Imp"],index=x_train.columns).sort_values(by = "Imp",ascending=False))
# Out:
#                                      Imp
# credit_amount                   0.151792
# account_balance                 0.134203
# age                             0.114810
# credit_duration_months          0.086347
# installment_rate                0.075011
# current_assets                  0.067739
# employment_duration             0.058191
# bank_credits                    0.044485
# residence_duration              0.042228
# previous_credit_payment_status  0.036902
# credit_purpose                  0.033662
# savings                         0.033167
# apartment_type                  0.029617
# telephone                       0.022454
# dependents                      0.021450
# marital_status                  0.020594
# occupation                      0.019561
# foreign_worker                  0.005947
# other_credits                   0.001838
# guarantor                       0.000000

# %%
importances=model.feature_importances_
indices=np.argsort(importances)

plt.figure(figsize=(12,30))
plt.title("Feature Importances")
plt.barh(range(len(indices)),importances[indices],color="violet",align="center")
plt.yticks(range(len(indices)),[feature_names[i] for i in indices])
plt.show()

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
from sklearn import metrics
estimator = DecisionTreeClassifier(random_state=1)
parameters={
          'max_depth':np.arange(4,10),
           'criterion':['gini'],
           'splitter':['best'],
           'min_impurity_decrease':[0.00001,0.0001],
           'max_features':['log2'],
            'min_samples_split':[60],
            #'random_state':[1]
          }

scorer =metrics.make_scorer(metrics.recall_score)

grid_obj =RandomizedSearchCV(estimator,parameters,scoring=scorer,cv=5)
grid_obj=grid_obj.fit(x_train,y_train)

estimator =grid_obj.best_estimator_

estimator.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, max_features='log2',
#                        min_impurity_decrease=0.0001, min_samples_split=60,
#                        random_state=1)

# %%
pred_train_estimator=estimator.predict(x_train)

# %%
pred_test_estimator=estimator.predict(x_test)

# %%
#calling the confusion matrix for train data 
make_confusion_matrix(y_train,pred_train_estimator)

# %%
#calling the confusion matrix for train data 
make_confusion_matrix(y_test,pred_test_estimator)

# %%
print("Recall on train data:",recall_score(y_train,pred_train_estimator))
print("Recall on test data:",recall_score(y_test,pred_test_estimator))
print("\n")
# Out:
# Recall on train data: 0.9839034205231388
# Recall on test data: 0.9458128078817734

# %%
print("Precision on train data:",precision_score(y_train,pred_train_estimator))
print("Precision on test data:",precision_score(y_test,pred_test_estimator))
print("\n")
# Out:
# Precision on train data: 0.740909090909091
# Precision on test data: 0.6832740213523132
